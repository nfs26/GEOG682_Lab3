# %% [markdown]
# Nina Smith
# 07/01/2019
# GEOG 682 Lab 3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Crime_2017.csv')

# %%
data
# Out:
#                                                 wkt_geom       CCN     DATE  \
# 0      Point (-77.02498381736047861 38.89981322477427...  17099955  6/12/17
# 1      Point (-77.07098904595119393 38.90769465590191...  17099960  6/12/17
# 2      Point (-77.04663978712287076 38.9091032074190295)  17099975  6/12/17
# 3      Point (-77.0097061689589566 38.96372943312384507)  17099979  6/12/17
# 4      Point (-77.02886695677204898 38.89523608044212...  17099985  6/12/17
# 5      Point (-77.01829165516194564 38.92204705397512...  17099996  6/12/17
# 6      Point (-77.04947342271367461 38.9052644847968665)  17100005  6/12/17
# 7      Point (-76.99130541227569324 38.93784873962781...  17100009  6/12/17
# 8      Point (-77.05081574253719623 38.89603033899959...  17100014  6/12/17
# 9      Point (-77.05756680414387461 38.90525176878495...  17100032  6/12/17
# 10     Point (-76.94089617859597752 38.90126030129675...  17100042  6/12/17
# ...

# %%
jan_data = data[data['DATE'].between('1/1/17','1/31/17')]

# %%
jan_num=len(jan_data)

# %%
jan_num variable = number of crimes committed in DC in the month of January 
jan_num=2496

# %%
d3 = data[data['DISTRICT']==3]
d3_num = len(d3)

# %% [markdown]
# d3num = number of crimes committed in District 3 in 2017
# d3num = 5434
# This number is not the same as the 2017 crime count for District 3 that I got in Lab 2 (which was 5964).  This could be because some events are coded to the wrong districts, so when the spatial join is performed, they are included in district 3 but they don't have a district 3 attribute.

# %%
d3_auto = d3[d3['OFFENSE']=="THEFT F/AUTO"]
d3_auto
# Out:
#                                                 wkt_geom       CCN      DATE  \
# 5      Point (-77.01829165516194564 38.92204705397512...  17099996   6/12/17
# 25     Point (-77.02838381221395991 38.92673837334142...  17101162   6/14/17
# 26     Point (-77.01893433591266103 38.9103811591353832)  17101172   6/14/17
# 74     Point (-77.02299834734563433 38.92742418932692...  17095239    6/5/17
# 87     Point (-77.03026851788845875 38.91112646496354...  17095360    6/5/17
# 88     Point (-77.02963591053969594 38.91483806305230...  17095374    6/5/17
# 143    Point (-77.02963152748601772 38.90428929193632...  17197682  11/15/17
# 156    Point (-77.02972055163131415 38.9242607533666245)  17197848  11/15/17
# 184    Point (-77.02172975821008549 38.92742443210578...  17183717  10/23/17
# 188    Point (-77.03098929977888076 38.92475588141714...  17183774  10/23/17
# 195    Point (-77.02534918122002239 38.92229796913235...  17188327  10/30/17
# ...

# %%
d3_auto_num=len(dc_auto)
d3_auto_num
# Out:
# 2337

# %% [markdown]
# d3_auto_num = number of thefts from autos in District 3
# d3_auto_num = 2337

# %%
x = d3_auto['LONGITUDE']
y = d3_auto['LATITUDE']
plt.scatter(x,y)
plt.show()
